# %% [markdown]
# # Train T5 for English → Romanian Translation
# # This notebook fine-tunes Google's T5 (t5-small) model using the WMT datasets.

# %%
from datasets import load_dataset
from transformers import T5Tokenizer, T5ForConditionalGeneration
from transformers import Trainer, TrainingArguments, DataCollatorForSeq2Seq
import evaluate
import torch
from evaluate import load

# %%
# Load and Preprocess Dataset
# Choose dataset: use 'wmt14', 'de-en' for English-German or 'wmt16', 'ro-en' for English-Romanian
# Also change the PREFIX and output paths accordingly
DATASET_NAME = "wmt16"
LANG_PAIR = "ro-en"
PREFIX = "translate English to Romanian: "

# Load a small subset for training
raw_dataset = load_dataset(DATASET_NAME, LANG_PAIR, split="train[:5000]")
#num_train_epochs=3

# %%
# Load Tokenizer and Model

tokenizer = T5Tokenizer.from_pretrained("t5-small")
model = T5ForConditionalGeneration.from_pretrained("t5-small")

# Tokenize Dataset

def preprocess(example):
    input_text = PREFIX + example["translation"]["en"]
    target_text = example["translation"]["ro"]
    model_inputs = tokenizer(input_text, max_length=128, truncation=True, padding="max_length")
    labels = tokenizer(target_text, max_length=128, truncation=True, padding="max_length")
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Apply preprocessing
tokenized_dataset = raw_dataset.map(preprocess, remove_columns=raw_dataset.column_names)
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]

# %%
# Set Up Training

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
training_args = TrainingArguments(
    output_dir="./t5-finetuned-en-ro", 
    per_device_train_batch_size=4,
    num_train_epochs=3,
    logging_dir="./logs",
    save_strategy="epoch",
    evaluation_strategy="no",
    report_to="none"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator
)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/transformers/training_args.py:1611: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /var/folders/qx/kwt2yzc57djflb63h7j_sxg40000gn/T/ipykernel_28409/1565333161.py:14: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
# Train the Model

trainer.train()

# Save Model and Tokenizer

#model.save_pretrained("./t5-finetuned-en-ro")
#tokenizer.save_pretrained("./t5-finetuned-en-ro")
# Save Model and Tokenizer
model.save_pretrained("./t5-small-finetuned-en-ro")
tokenizer.save_pretrained("./t5-small-finetuned-en-ro")
print(" T5 model trained and saved.")
# Out:
#     <div>
#
#       <progress value='3750' max='3750' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3750/3750 08:40, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.151200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.107900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.100300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.099300</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.097100</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.093500</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.090200</td>
#     </tr>
#   </tbody>
# </table><p>
#  T5 model trained and saved.

# %%
# Evaluate BLEU Score
bleu = load("bleu")
model.eval()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

predictions, references = [], []
sample_dataset = raw_dataset.select(range(50))

for idx, example in enumerate(sample_dataset):
    input_text = PREFIX + example["translation"]["en"]
    target_text = example["translation"]["ro"]

    inputs = tokenizer(input_text, return_tensors="pt", padding=True, truncation=True).to(device)
    with torch.no_grad():
        output_tokens = model.generate(**inputs, max_length=128)

    prediction = tokenizer.decode(output_tokens[0], skip_special_tokens=True)

    print("\n🔹 INPUT:", input_text)
    print("🔸 TARGET:", target_text)
    print("✅ PREDICTION:", prediction)

    if prediction.strip():
        predictions.append(prediction.strip().lower())
        references.append([target_text.strip().lower()])

# Compute BLEU with smoothing if available
if predictions and references:
    try:
        bleu_result = bleu.compute(predictions=predictions, references=references, smooth=True)
        print(f"\n✅ BLEU score on 50 samples: {bleu_result['bleu']:.4f}")
    except ZeroDivisionError:
        print("❌ BLEU score could not be computed due to zero n-gram overlap.")
else:
    print("⚠️ No valid predictions or references to evaluate BLEU.")
# Out:
# 🔹 INPUT: translate English to Romanian: Membership of Parliament: see Minutes
# 🔸 TARGET: Componenţa Parlamentului: a se vedea procesul-verbal
# ✅ PREDICTION: Componenţa Parlamentului: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Approval of Minutes of previous sitting: see Minutes
# 🔸 TARGET: Aprobarea procesului-verbal al şedinţei precedente: a se vedea procesul-verbal
# ✅ PREDICTION: Aprobarea procesului-verbal al şedinţei precedente: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Membership of Parliament: see Minutes
# 🔸 TARGET: Componenţa Parlamentului: a se vedea procesul-verbal
# ✅ PREDICTION: Componenţa Parlamentului: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Verification of credentials: see Minutes
# 🔸 TARGET: Verificarea prerogativelor: a se vedea procesul-verbal
# ✅ PREDICTION: Verificarea prerogativelor: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Documents received: see Minutes
# 🔸 TARGET: Depunere de documente: a se vedea procesul-verbal
# ✅ PREDICTION: Depunerea documentelor: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Written statements and oral questions (tabling): see Minutes
# 🔸 TARGET: Declaraţii scrise şi întrebări orale (depunere): consultaţi procesul-verbal
# ✅ PREDICTION: Declaraţii scrise şi întrebări orale (depunere): consultaţi procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Petitions: see Minutes
# 🔸 TARGET: Petiţii: a se vedea procesul-verbal
# ✅ PREDICTION: Petiţii: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Texts of agreements forwarded by the Council: see Minutes
# 🔸 TARGET: Transmiterea de către Consiliu a textelor acordurilor: a se vedea procesul-verbal
# ✅ PREDICTION: Transmiterea de către Consiliu a textelor acordurilor: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Action taken on Parliament's resolutions: see Minutes
# 🔸 TARGET: Cursul dat rezoluţiilor Parlamentului: a se vedea procesul-verbal
# ✅ PREDICTION: Continuări ale rezoluţiilor Parlamentului: consultaţi procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Agenda for next sitting: see Minutes
# 🔸 TARGET: Ordinea de zi a următoarei şedinţe: a se vedea procesul-verbal
# ✅ PREDICTION: Ordinea de zi a următoarei şedinţe: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Closure of sitting
# 🔸 TARGET: Ridicarea şedinţei
# ✅ PREDICTION: Ridicarea şedinţei
#
# 🔹 INPUT: translate English to Romanian: (The sitting was closed at 7.45 p.m.)
# 🔸 TARGET: (Se levanta la sesión a las 19.45 horas)
# ✅ PREDICTION: (La seduta è tolta alle 19.45)
#
# 🔹 INPUT: translate English to Romanian: Election of Vice-Presidents of the European Parliament (deadline for submitting nominations): see Minutes
# 🔸 TARGET: Alegerea vicepreşedinţilor Parlamentului European (termenul de depunere a candidaturilor): consultaţi procesul-verbal
# ✅ PREDICTION: Alegerea vicepreşedinţilor Parlamentului European (termenul de depunere a candidaturilor): consultaţi procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: (The sitting was suspended at 12.40 p.m. and resumed at 3.00 p.m.)
# 🔸 TARGET: (Die Sitzung wird um 12.40 Uhr unterbrochen und um 15.00 Uhr wiederaufgenommen).
# ✅ PREDICTION: (La seduta, sospesa alle 12.40, è ripresa alle 15.00)
#
# 🔹 INPUT: translate English to Romanian: Election of Quaestors of the European Parliament (deadline for submitting nominations): see Minutes
# 🔸 TARGET: Alegerea chestorilor Parlamentului European (termenul de depunere a candidaturilor): consultaţi procesul-verbal
# ✅ PREDICTION: Alegerea calificatorilor Parlamentului European (termenul de depunere a candidaturilor): consultaţi procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: (The sitting was suspended at 3.25 p.m. and resumed at 6.00 p.m.)
# 🔸 TARGET: (Die Sitzung wird um 15.25 Uhr unterbrochen und um 18.00 Uhr wiederaufgenommen).
# ✅ PREDICTION: (La seduta, sospesa alle 15.25, è ripresa alle 18.00)
#
# 🔹 INPUT: translate English to Romanian: Agenda for next sitting: see Minutes
# 🔸 TARGET: Ordinea de zi a următoarei şedinţe: a se vedea procesul-verbal
# ✅ PREDICTION: Ordinea de zi a următoarei şedinţe: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Closure of sitting
# 🔸 TARGET: Ridicarea şedinţei
# ✅ PREDICTION: Ridicarea şedinţei
#
# 🔹 INPUT: translate English to Romanian: (The sitting was closed at 6.15 p.m.)
# 🔸 TARGET: (Die Sitzung wird um 18.15 Uhr geschlossen.)
# ✅ PREDICTION: (La seduta è tolta alle 18.15)
#
# 🔹 INPUT: translate English to Romanian: Opening of the sitting
# 🔸 TARGET: Deschiderea şedinţei
# ✅ PREDICTION: Deschiderea şedinţei
#
# 🔹 INPUT: translate English to Romanian: (The sitting was opened at 9.35 a.m.)
# 🔸 TARGET: (Die Sitzung wird um 9.35 Uhr eröffnet.)
# ✅ PREDICTION: (La seduta è aperta alle 9.35)
#
# 🔹 INPUT: translate English to Romanian: Documents received: see Minutes
# 🔸 TARGET: Depunerea documentelor: a se vedea procesul-verbal
# ✅ PREDICTION: Depunerea documentelor: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Approval of Minutes of previous sitting: see Minutes
# 🔸 TARGET: Aprobarea procesului-verbal al şedinţei precedente: a se vedea procesul-verbal
# ✅ PREDICTION: Aprobarea procesului-verbal al şedinţei precedente: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Membership of Parliament: see Minutes
# 🔸 TARGET: Componenţa Parlamentului: a se vedea procesul-verbal
# ✅ PREDICTION: Componenţa Parlamentului: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Membership of committees (deadline for tabling amendments): see Minutes
# 🔸 TARGET: Componenţa comisiilor (termenul de depunere a amendamentelor): consultaţi procesul-verbal
# ✅ PREDICTION: Componenţa comisiilor (termenul de depunere a amendamentelor): consultaţi procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: (The sitting was suspended at 7 p.m. and resumed at 9 p.m.)
# 🔸 TARGET: (La seduta, sospesa alle 19.00, è ripresa alle 21.00)
# ✅ PREDICTION: (La seduta, sospesa alle 19.00, è ripresa alle 21.00)
#
# 🔹 INPUT: translate English to Romanian: Agenda for next sitting: see Minutes
# 🔸 TARGET: Ordinea de zi a următoarei şedinţe: a se vedea procesul-verbal
# ✅ PREDICTION: Ordinea de zi a următoarei şedinţe: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Closure of sitting
# 🔸 TARGET: Ridicarea şedinţei
# ✅ PREDICTION: Ridicarea şedinţei
#
# 🔹 INPUT: translate English to Romanian: (The sitting was suspended at 23.25 p.m.)
# 🔸 TARGET: (Die Sitzung wird um 23.25 Uhr geschlossen.)
# ✅ PREDICTION: (La seduta, sospesa alle 23.25)
#
# 🔹 INPUT: translate English to Romanian: Documents received: see Minutes
# 🔸 TARGET: Depunerea documentelor: a se vedea procesul-verbal
# ✅ PREDICTION: Depunerea documentelor: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Communication of Council common positions: see Minutes
# 🔸 TARGET: Comunicarea poziţiilor comune ale Parlamentului: a se vedea procesul-verbal
# ✅ PREDICTION: Comunicarea poziţiilor comune ale Parlamentului: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: (The sitting was suspended at 11.35 a.m. and resumed for voting time at noon)
# 🔸 TARGET: (La séance, suspendue à 11h35 dans l'attente de l'Heure des votes, est reprise à midi)
# ✅ PREDICTION: (La seduta, sospesa alle 11.35, è ripresa alle ripresa alle midi)
#
# 🔹 INPUT: translate English to Romanian: Approval of Minutes of previous sitting: see Minutes
# 🔸 TARGET: Aprobarea procesului-verbal al şedinţei precedente: a se vedea procesul-verbal
# ✅ PREDICTION: Aprobarea procesului-verbal al şedinţei precedente: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Committee of Inquiry into the crisis of the Equitable Life Assurance Society (extension of mandate): see Minutes
# 🔸 TARGET: Comisia de anchetă privind criza societăţii de asigurări "Equitable Life” (prelungirea mandatului): consultaţi procesul-verbal
# ✅ PREDICTION: Comisia de anchetă privind criza societăţii de asigurări Equitable Life (prelungirea mandatului): consultaţi procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Announcement by the President: see Minutes
# 🔸 TARGET: Comunicarea Preşedintelui: consultaţi procesul-verbal
# ✅ PREDICTION: Comunicarea Preşedinţiei: consultaţi procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: 1.
# 🔸 TARGET: 1.
# ✅ PREDICTION: 1.
#
# 🔹 INPUT: translate English to Romanian: Membership of committees (vote)
# 🔸 TARGET: Componenţa comisiilor (vot)
# ✅ PREDICTION: Componenţa comisiilor (vot)
#
# 🔹 INPUT: translate English to Romanian: 2.
# 🔸 TARGET: 2.
# ✅ PREDICTION: 2.
#
# 🔹 INPUT: translate English to Romanian: Amendment of the ACP-EC Partnership Agreement (vote)
# 🔸 TARGET: Modificarea Acordului de parteneriat ACP-CE ("Acordul de la Cotonou”) (vot)
# ✅ PREDICTION: Modificarea Acordului de parteneriat ACP-CE (vot)
#
# 🔹 INPUT: translate English to Romanian: 4.
# 🔸 TARGET: 4.
# ✅ PREDICTION: 4.
#
# 🔹 INPUT: translate English to Romanian: Certification of train drivers operating locomotives and trains on the railway system in the Community (vote)
# 🔸 TARGET: Certificarea mecanicilor de locomotivă care conduc locomotive şi trenuri în sistemul feroviar comunitar (vot)
# ✅ PREDICTION: Certificarea mecanicilor de locomotivă care operează locomotive şi trenuri în sistemul feroviar comunitar (vot)
#
# 🔹 INPUT: translate English to Romanian: 6.
# 🔸 TARGET: 6.
# ✅ PREDICTION: 6.
#
# 🔹 INPUT: translate English to Romanian: Law applicable to non-contractual obligations ("ROME II") (vote)
# 🔸 TARGET: Legea aplicabilă obligaţiilor necontractuale ("Roma II”) (vot)
# ✅ PREDICTION: Legea aplicabilă obligaţiilor necontractuale ("Roma II") (vot)
#
# 🔹 INPUT: translate English to Romanian: 8.
# 🔸 TARGET: 8.
# ✅ PREDICTION: 8.
#
# 🔹 INPUT: translate English to Romanian: Seventh and eighth annual reports on arms exports (vote)
# 🔸 TARGET: Al şaptelea şi al optulea raport anual privind exportul de armament (vot)
# ✅ PREDICTION: Al şaptelea şi al optulea raport anual privind exportul de arme (vot)
#
# 🔹 INPUT: translate English to Romanian: Corrections to votes and voting intentions: see Minutes
# 🔸 TARGET: Corectările voturilor şi intenţiile de vot: a se vedea procesul-verbal
# ✅ PREDICTION: Corectările voturilor şi intenţiile de vot: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Membership of committees and delegations: see Minutes
# 🔸 TARGET: Componenţa comisiilor şi a delegaţiilor: a se vedea procesul-verbal
# ✅ PREDICTION: Componenţa comisiilor şi a delegaţiilor: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Request for waiver of parliamentary immunity: see Minutes
# 🔸 TARGET: Cerere de ridicare a imunităţii parlamentare: consultaţi procesul-verbal
# ✅ PREDICTION: Cerere de ridicare a imunităţii parlamentare: consultaţi procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Decisions concerning certain documents: see Minutes
# 🔸 TARGET: Decizii privind anumite documente: a se vedea procesul-verbal
# ✅ PREDICTION: Decizii privind anumite documente: a se vedea procesul-verbal
#
# 🔹 INPUT: translate English to Romanian: Written statements for entry in the register (Rule 116): see Minutes
# 🔸 TARGET: Declaraţii scrise înscrise în registru (articolul 116 din Regulamentul de procedură): a se vedea procesul-verbal
# ✅ PREDICTION: Declaraţii scrise înscrise în registru (articolul 116 din Regulamentul de procedură): a se vedea procesul-verbal
#
# ✅ BLEU score on 50 samples: 0.7348
